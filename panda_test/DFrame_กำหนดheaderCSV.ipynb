# %%
import pandas as pd
colsName = ['Name','Category','Price']
df = pd.read_csv('product_data2.csv', encoding='utf-8', names=colsName)

# %%
df
# Out:
#          Name            Category Price
# 0  ชื่อสินค้า            หมวดหมู่  ราคา
# 1     คีบอร์ด  อุปกรณ์คอมพิวเตอร์  1000
# 2       เมาส์  อุปกรณ์คอมพิวเตอร์   500
# 3      ตุ๊กตา             ของเล่น   300
