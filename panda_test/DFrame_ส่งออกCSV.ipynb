# %%
import pandas as pd

name = ['คีบอร์ด','เมาส์','ตุ๊กตา']
category = ['อุปกรณ์คอมพิวเตอร์','อุปกรณ์คอมพิวเตอร์','ของเล่น']
price = [1000, 500, 300]

# %%
#series
name_series = pd.Series(name)
category_series = pd.Series(category)
price_series = pd.Series(price)

# %%
# Create a DataFrame from the lists
frame = {'ชื่อสินค้า': name_series,
         'หมวดหมู่': category_series,  
         'ราคา': price_series}

# %%
df = pd.DataFrame(frame)

# %%
df.set_index('ชื่อสินค้า', inplace=True)

# %%
df
# Out:
#                       หมวดหมู่  ราคา
# ชื่อสินค้า
# คีบอร์ด     อุปกรณ์คอมพิวเตอร์  1000
# เมาส์       อุปกรณ์คอมพิวเตอร์   500
# ตุ๊กตา                 ของเล่น   300

# %%
df.to_csv('product_data2.csv', header=True,index=True,encoding='utf-8-sig')
