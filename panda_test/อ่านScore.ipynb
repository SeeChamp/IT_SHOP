# %%
import pandas as pd
df = pd.read_csv('Score2.csv', index_col='Name')  # Read the csv file

# %%
df
# Out:
#           Score  Age Gender Grade
# Name
# อาทิต        90   20    ชาย     A
# นิตยา        75   18   หญิง     B
# โจโจ้        88   22    ชาย     A
# แก้มใส       65   19   หญิง     C
# ตั้กแตน      82   23   หญิง     A
# เก๋ไก๋       50   20   หญิง     D
# วุฒิชัย      45   17    ชาย     F
# ชัยสิทธ์     62   18    ชาย     C
# ธนาวุฒิ      95   19    ชาย     A

# %%
df.Score.max()  # Find the maximum score
# Out:
# np.int64(95)

# %%
df.Score.min()  # Find the minimum score
# Out:
# np.int64(45)

# %%
df.Score.mean()  # Calculate the average score
# Out:
# np.float64(72.44444444444444)

# %%
df.Score.std()  # Calculate the standard deviation of scores
# Out:
# np.float64(17.95209675157133)

# %%
df.count()  # Count the number of entries in each column
# Out:
# Score     9
# Age       9
# Gender    9
# Grade     9
# dtype: int64

# %%
df.sum()  # Sum of scores
# Out:
# Score                                 652
# Age                                   176
# Gender    ชายหญิงชายหญิงหญิงหญิงชายชายชาย
# Grade                           ABACADFCA
# dtype: object

# %%
df.Score.sum()  # Sum of scores in the Score column
# Out:
# np.int64(652)

# %%
df.Score.sum()/df.Score.count()  # Calculate the average score using sum and count
# Out:
# np.float64(72.44444444444444)

# %%
df.dtypes  # Check the data type of the Score column
# Out:
# Score      int64
# Age        int64
# Gender    object
# Grade     object
# dtype: object

# %%
df.Grade = df.Grade.astype('category')  # Convert the Grade column to categorical type

# %%
df.dtypes
# Out:
# Score        int64
# Age          int64
# Gender      object
# Grade     category
# dtype: object
