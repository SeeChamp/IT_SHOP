# %%
import  pandas as pd

data_students = {
    'Name': ['อาทิต', 'นิตยา', 'โจโจ้', 'แก้มใส','ตั้กแตน','เก๋ไก๋','วุฒิชัย','ชัยสิทธ์','ธนาวุฒิ'],
    'Score': [90,75,88,65,82,50,45,62,95],
    'Age': [20,18,22,19,23,20,17,18,19],
    'Gender': ['ชาย','หญิง','ชาย','หญิง','หญิง','หญิง','ชาย','ชาย','ชาย'],
    'Grade': ['A','B','A','C','A','D','F','C','A']
    }

# %%
df = pd.DataFrame(data_students)  # Create a DataFrame from the dictionary

# %%
df
# Out:
#        Name  Score  Age Gender Grade
# 0     อาทิต     90   20    ชาย     A
# 1     นิตยา     75   18   หญิง     B
# 2     โจโจ้     88   22    ชาย     A
# 3    แก้มใส     65   19   หญิง     C
# 4   ตั้กแตน     82   23   หญิง     A
# 5    เก๋ไก๋     50   20   หญิง     D
# 6   วุฒิชัย     45   17    ชาย     F
# 7  ชัยสิทธ์     62   18    ชาย     C
# 8   ธนาวุฒิ     95   19    ชาย     A

# %%
df.to_csv('Score1.csv',header=True,index=True,encoding='utf-8-sig')  # Save the DataFrame to a CSV file without the index
