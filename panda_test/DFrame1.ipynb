# %%
import pandas as pd
datas = [10, 20, 30, 40, 50]

# %%
df = pd.DataFrame(datas)
print(df)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
datas_tp = (59,60,61,62,63)

# %%
cols = ['อายุ']
df = pd.DataFrame(datas_tp, columns=cols)
df
# Out:
#    อายุ
# 0    59
# 1    60
# 2    61
# 3    62
# 4    63
