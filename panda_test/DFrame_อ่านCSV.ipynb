# %%
import pandas as pd
df = pd.read_csv('product_data.csv', encoding='utf-8', usecols=cols , index_col='ชื่อสินค้า')
# การอ่านไฟล์ CSV บางคอลัมน์ โดยใช้ usecols = cols 
cols = ['ชื่อสินค้า', 'ราคา']

# %%
df
# Out:
#             ราคา
# ชื่อสินค้า
# คีบอร์ด     1000
# เมาส์        500
# ตุ๊กตา       300
