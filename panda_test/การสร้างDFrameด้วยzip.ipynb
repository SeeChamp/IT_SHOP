# %%
import pandas as pd
Name = ['เมาส์','โยโย่','กระทะไฟฟ้า']
category = ['IT','ของเล่น','ห้องครัว']
price = [1000,500,3000]
datas = list(zip(Name, category, price))

# %%
columns = ['ชื่อสินค้า', 'หมวดหมู่', 'ราคา']
df  = pd.DataFrame(datas,columns=columns)

# %%
df
# Out:
#    ชื่อสินค้า  หมวดหมู่  ราคา
# 0       เมาส์        IT  1000
# 1       โยโย่   ของเล่น   500
# 2  กระทะไฟฟ้า  ห้องครัว  3000
